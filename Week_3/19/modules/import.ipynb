# %%
import math

math.sqrt(16)

# %%
from math import sqrt,pi

print(sqrt(16))
print(sqrt(25))
print(pi)

# %%
import numpy as np

np.array([1,2,3,4,5])

# %%
from packages.math import addition

print(addition(10,10))

# %%
from packages import math

math.addition(19,121)
# Out:
# 140
