# %%
## Creating a tuple

empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tuple))
# Out:
# <class 'list'>
# <class 'type'>

# %%
mixed = ("Parthasarathy",1,23)
print(mixed)
# Out:
# ('Parthasarathy', 1, 23)

# %%
#Accessing the elements

print(mixed[::-1])
# Out:
# (23, 1, 'Parthasarathy')

# %%
## Tuple operations

number = (1,2,3,4,5,6)
concat = mixed + number

print(concat)
# Out:
# ('Parthasarathy', 1, 23, 1, 2, 3, 4, 5, 6)

# %%
mixed * 3
# Out:
# ('Parthasarathy', 1, 23, 'Parthasarathy', 1, 23, 'Parthasarathy', 1, 23)

# %%
number * 3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
#immutable nature of tuples

lst = [1,2,3,4,5]
print(lst)

lst[1] = "Partha"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Partha', 3, 4, 5]

# %%
# number[1] = "2"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 number[1] = "2"
#
# TypeError: 'tuple' object does not support item assignment

# %%
##Tuple Methods

print(number.count(1))
print(number.index(3))
# Out:
# 1
# 2

# %%
#Packing and unpacking tuple

packed = 1 , "Hello", 3.14
print(packed)

#Unpacking a tuple

a,b,c = packed

print(a)
print(b)
print(c)
# Out:
# (1, 'Hello', 3.14)
# 1
# Hello
# 3.14

# %%
# Unpacking with *

first ,*middle,last = number
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
##Nested lsit
lst =[[1,2,3,4,],[2,4,6,8,10],["Helllo",1,20]]
lst[0][0:3] 
##Nested tuples

lst =[[1,2,3,4,],[2,4,6,8,10],("Helllo",1,20)]
lst[2][0:3] 

nested_tuple = ((1,2,3), ("a","b","c"),(True, False))

print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
#Iterating 

for sub in nested_tuple:
    for items in sub:
        print(items,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
