# %% [markdown]
# #### Logging with Multiple Loggers
# You can create multiple loggers for different parts of your application.

# %%
import logging
## create a logger for module1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

##create a logger for module 2

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logger3=logging.getLogger("module3")
logger3.setLevel(logging.ERROR)

# Configure logging settings
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
## Log message with different loggers

logger1.debug("This is debug message for module1")
logger2.warning("This is a warning message for module 2")
logger3.error("This is an error message")
# Out:
# 2026-03-11 10:33:12 - module1 - DEBUG - This is debug message for module1
# 2026-03-11 10:33:12 - module2 - WARNING - This is a warning message for module 2
# 2026-03-11 10:33:12 - module3 - ERROR - This is an error message
